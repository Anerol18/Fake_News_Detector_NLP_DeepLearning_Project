# %% [markdown]
# # FAKENEWS DETECTOR PLAYGROUND
#
# In this playground, for now, we :
# - verify the environement is working well,
# - load a big Model already existing (Bert Fake news detector),
# - load a dataset about covid's fakenews(nanny's one)
#
#
#
# ### Environment verifications

# %%
# !conda info
# Out:
#      active environment : DL-torch-arm64
#     active env location : /Applications/anaconda3/envs/DL-torch-arm64
#             shell level : 2
#        user config file : /Users/antoineherbet/.condarc
#  populated config files : /Users/antoineherbet/.condarc
#           conda version : 24.7.1
#     conda-build version : 24.5.1
#          python version : 3.12.2.final.0
#                  solver : libmamba (default)
#        virtual packages : __archspec=1=m1
#                           __conda=24.7.1=0
#                           __osx=14.5=0
#                           __unix=0=0
#        base environment : /Applications/anaconda3  (writable)
#       conda av data dir : /Applications/anaconda3/etc/conda
#   conda av metadata url : None
#            channel URLs : https://conda.anaconda.org/conda-forge/osx-arm64
#                           https://conda.anaconda.org/conda-forge/noarch
#                           https://repo.anaconda.com/pkgs/main/osx-arm64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-arm64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /Applications/anaconda3/pkgs
#                           /Users/antoineherbet/.conda/pkgs
#        envs directories : /Applications/anaconda3/envs
#                           /Users/antoineherbet/.conda/envs
#                platform : osx-arm64
#              user-agent : conda/24.7.1 requests/2.32.2 CPython/3.12.2 Darwin/23.5.0 OSX/14.5 solver/libmamba conda-libmamba-solver/24.1.0 libmambapy/1.5.8 aau/0.4.4 c/. s/. e/.
#                 UID:GID : 501:20
#              netrc file : None
#            offline mode : False

# %%
import torch

# If Metal Performance Shader (mps) is not available tell me:
if not torch.backends.mps.is_available():
    if not torch.backends.mps.is_built():
        print("MPS not available because the current PyTorch install was not "
              "built with MPS enabled.")
    else:
        print("MPS not available because the current MacOS version is not 12.3+ "
              "and/or you do not have an MPS-enabled device on this machine.")

# If mps is available directly put it on the device.
else:
    mps_device = torch.device("mps")

# Is mps available?

gpu_avail = torch.backends.mps.is_available() 
print(f"Is Metal Performance Shader (mps) available? {gpu_avail}")
# Out:
# Is Metal Performance Shader (mps) available? True

# %%
# For intel devices
'''
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)
'''
# Out:
# '\ndevice = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")\nmodel.to(device)\n'

# %%
## Import a Comparator Model

# %%
# mute Llama model (too big)
# let's import a model

# from transformers import AutoTokenizer, AutoModelForSequenceClassification

#tokenizer = AutoTokenizer.from_pretrained("FakeNewsLlama/HealthTrueFakeClassifierFinal")
#model = AutoModelForSequenceClassification.from_pretrained("FakeNewsLlama/HealthTrueFakeClassifierFinal")

# %%
# Load model directly : BERT Fake news detector
#from transformers import AutoTokenizer, AutoModelForSequenceClassification

#tokenizer = AutoTokenizer.from_pretrained("jy46604790/Fake-News-Bert-Detect")
#model = AutoModelForSequenceClassification.from_pretrained("jy46604790/Fake-News-Bert-Detect")

# %% [markdown]
# This model might be a good one to compare the final results of our training.

# %% [markdown]
# ## Load a Fake News datasets (nanyy1025)

# %%
# load a dataset

from datasets import load_dataset

ds = load_dataset("nanyy1025/covid_fake_news")

# %%
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tweet', 'label'],
#         num_rows: 6420
#     })
#     validation: Dataset({
#         features: ['id', 'tweet', 'label'],
#         num_rows: 2140
#     })
#     test: Dataset({
#         features: ['id', 'tweet', 'label'],
#         num_rows: 2140
#     })
# })

# %%
for id in range(50):
  if ds["train"][id]['label'] == 'fake':
    print(ds["train"][id])
# Out:
# {'id': 3, 'tweet': 'Politically Correct Woman (Almost) Uses Pandemic as Excuse Not to Reuse Plastic Bag https://t.co/thF8GuNFPe #coronavirus #nashville', 'label': 'fake'}
# {'id': 8, 'tweet': 'Obama Calls Trump’s Coronavirus Response A Chaotic Disaster https://t.co/DeDqZEhAsB', 'label': 'fake'}
# {'id': 9, 'tweet': '???Clearly, the Obama administration did not leave any kind of game plan for something like this.??�', 'label': 'fake'}
# {'id': 10, 'tweet': 'Retraction—Hydroxychloroquine or chloroquine with or without a macrolide for treatment of COVID-19: a multinational registry analysis - The Lancet https://t.co/L5V2x6G9or', 'label': 'fake'}
# {'id': 12, 'tweet': 'The NBA is poised to restart this month. In March we reported on how the Utah Jazz got 58 coronavirus tests in a matter of hours at a time when U.S. testing was sluggish. https://t.co/I8YjjrNoTh https://t.co/o0Nk6gpyos', 'label': 'fake'}
# {'id': 17, 'tweet': "Because of Donald Trump's negligence and incompetence:\n \n- More than 110,000 people have died\n- We have nearly 2 million cases of COVID-19\n- Over 20 million Americans are out of work\n \nAnd yet he’s patting himself on the back. Unbelievable.", 'label': 'fake'}
# {'id': 20, 'tweet': 'Multiple Facebook posts claim that “Aussies will be fined if they are found to be talking about conspiracies to do with [COVID-19]”. The posts included a screenshot of a segment from an Australian breakfast television show as evidence for the claim.', 'label': 'fake'}
# {'id': 21, 'tweet': 'No Nobel Prize laureate Tasuku Honjo didn\'t say the coronavirus is "not natural" as a post on Facebook claims. In fact Professor Honjo said he\'s "greatly saddened" his name was used to spread misinformation. This and more in the latest #CoronaCheck: https://t.co/rLcTuIcIHO https://t.co/WdoocCiXFu', 'label': 'fake'}
# {'id': 23, 'tweet': 'BREAKING NEWS# The president Cryill Ramaphosa has asked all foreign nations to depart south Africa before 21 june 2020 due to increasing cases of COVID 19 .', 'label': 'fake'}
# {'id': 26, 'tweet': 'Elon Musck To New Baby; Get A Job Kid! https://t.co/bc8Re0Ai3Y #christmas #covid19 #elonmusk #achristmascarol', 'label': 'fake'}
# {'id': 27, 'tweet': '_A new alcohol-free sanitizer has been developed by the Dedan Kimathi University in Kenya._', 'label': 'fake'}
# {'id': 31, 'tweet': '.@realDonaldTrump has shifted his focus at different moments in the #CoronavirusOutbreak. We updated our running timeline of his response to the virus. https://t.co/pgXjssaRCB Reply to us with any recent Trump moments you think belong on this running list. https://t.co/g4WYcppDSO', 'label': 'fake'}
# {'id': 32, 'tweet': 'Doctored image of President Donald Trump shared claiming he asked people to chant Hare Krishna Hare Rama.', 'label': 'fake'}
# {'id': 34, 'tweet': 'CDC Recommends Mothers Stop Breastfeeding To Boost Vaccine Efficacy', 'label': 'fake'}
# {'id': 35, 'tweet': 'Singapore Airlines Haults All Flights Due To Coronavirus Outbreak https://t.co/ANHxHm1DPK', 'label': 'fake'}
# {'id': 36, 'tweet': 'Florida Governor Ron DeSantis Botches COVID-19 Response - By banning Corona beer in order to flatten pandemic curve.', 'label': 'fake'}
# {'id': 38, 'tweet': 'NYT invented the video of a doctor fighting coronavirus in hospital.', 'label': 'fake'}
# {'id': 40, 'tweet': 'ALERT: Americans With Coronavirus Symptoms Are Being Asked To Cough Directly Onto President Trump', 'label': 'fake'}
# {'id': 42, 'tweet': 'Football player Cristiano Ronaldo turned all his hotels into hospitals to help coronavirus patients and is paying doctors and the staff.', 'label': 'fake'}
# {'id': 50, 'tweet': 'Scientists at AstraZeneca complain their work on a coronavirus vaccine keeps being delayed by Noddy Holder ringing up to ask if it will be ready by Christmas https://t.co/2lmYzTnAPx', 'label': 'fake'}

# %% [markdown]
# ## Load a small model to train (tiny mistral)

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("reciprocate/tiny-mistral")
model = AutoModelForSequenceClassification.from_pretrained("reciprocate/tiny-mistral")

# %%
inputs = tokenizer("Hello, my dog is cute", return_tensors="jax")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 inputs = tokenizer("Hello, my dog is cute", return_tensors="jax")
#
# File /Applications/anaconda3/envs/DL-torch-arm64/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:3073, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3071     if not self._in_target_context_manager:
#    3072         self._switch_to_input_mode()
# -> 3073     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    3074 if text_target is not None:
#    3075     self._switch_to_target_mode()
#
# File /Applications/anaconda3/envs/DL-torch-arm64/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:3181, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3160     return self.batch_encode_plus(
#    3161         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3162         add_special_tokens=add_special_tokens,
#    (...)
#    3178         **kwargs,
#    3179     )
#    3180 else:
# -> 3181     return self.encode_plus(
#    3182         text=text,
#    3183         text_pair=text_pair,
#    3184         add_special_tokens=add_special_tokens,
#    3185         padding=padding,
#    3186         truncation=truncation,
#    3187         max_length=max_length,
#    3188         stride=stride,
#    3189         is_split_into_words=is_split_into_words,
#    3190         pad_to_multiple_of=pad_to_multiple_of,
#    3191         return_tensors=return_tensors,
#    3192         return_token_type_ids=return_token_type_ids,
#    3193         return_attention_mask=return_attention_mask,
#    3194         return_overflowing_tokens=return_overflowing_tokens,
#    3195         return_special_tokens_mask=return_special_tokens_mask,
#    3196         return_offsets_mapping=return_offsets_mapping,
#    3197         return_length=return_length,
#    3198         verbose=verbose,
#    3199         split_special_tokens=split_special_tokens,
#    3200         **kwargs,
#    3201     )
#
# File /Applications/anaconda3/envs/DL-torch-arm64/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:3255, in PreTrainedTokenizerBase.encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3245 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3246 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3247     padding=padding,
#    3248     truncation=truncation,
#    (...)
#    3252     **kwargs,
#    3253 )
# -> 3255 return self._encode_plus(
#    3256     text=text,
#    3257     text_pair=text_pair,
#    3258     add_special_tokens=add_special_tokens,
#    3259     padding_strategy=padding_strategy,
#    3260     truncation_strategy=truncation_strategy,
#    3261     max_length=max_length,
#    3262     stride=stride,
#    3263     is_split_into_words=is_split_into_words,
#    3264     pad_to_multiple_of=pad_to_multiple_of,
#    3265     return_tensors=return_tensors,
#    3266     return_token_type_ids=return_token_type_ids,
#    3267     return_attention_mask=return_attention_mask,
#    3268     return_overflowing_tokens=return_overflowing_tokens,
#    3269     return_special_tokens_mask=return_special_tokens_mask,
#    3270     return_offsets_mapping=return_offsets_mapping,
#    3271     return_length=return_length,
#    3272     verbose=verbose,
#    3273     split_special_tokens=kwargs.pop("split_special_tokens", self.split_special_tokens),
#    3274     **kwargs,
#    3275 )
#
# File /Applications/anaconda3/envs/DL-torch-arm64/lib/python3.10/site-packages/transformers/tokenization_utils_fast.py:601, in PreTrainedTokenizerFast._encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#     578 def _encode_plus(
#     579     self,
#     580     text: Union[TextInput, PreTokenizedInput],
#    (...)
#     598     **kwargs,
#     599 ) -> BatchEncoding:
#     600     batched_input = [(text, text_pair)] if text_pair else [text]
# --> 601     batched_output = self._batch_encode_plus(
#     602         batched_input,
#     603         is_split_into_words=is_split_into_words,
#     604         add_special_tokens=add_special_tokens,
#     605         padding_strategy=padding_strategy,
#     606         truncation_strategy=truncation_strategy,
#     607         max_length=max_length,
#     608         stride=stride,
#     609         pad_to_multiple_of=pad_to_multiple_of,
#     610         return_tensors=return_tensors,
#     611         return_token_type_ids=return_token_type_ids,
#     612         return_attention_mask=return_attention_mask,
#     613         return_overflowing_tokens=return_overflowing_tokens,
#     614         return_special_tokens_mask=return_special_tokens_mask,
#     615         return_offsets_mapping=return_offsets_mapping,
#     616         return_length=return_length,
#     617         verbose=verbose,
#     618         split_special_tokens=split_special_tokens,
#     619         **kwargs,
#     620     )
#     622     # Return tensor is None, then we can remove the leading batch axis
#     623     # Overflowing tokens are returned as a batch of output so we keep them in this case
#     624     if return_tensors is None and not return_overflowing_tokens:
#
# File /Applications/anaconda3/envs/DL-torch-arm64/lib/python3.10/site-packages/transformers/tokenization_utils_fast.py:576, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens)
#     574 for input_ids in sanitized_tokens["input_ids"]:
#     575     self._eventual_warn_about_too_long_sequence(input_ids, max_length, verbose)
# --> 576 return BatchEncoding(sanitized_tokens, sanitized_encodings, tensor_type=return_tensors)
#
# File /Applications/anaconda3/envs/DL-torch-arm64/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:227, in BatchEncoding.__init__(self, data, encoding, tensor_type, prepend_batch_axis, n_sequences)
#     223     n_sequences = encoding[0].n_sequences
#     225 self._n_sequences = n_sequences
# --> 227 self.convert_to_tensors(tensor_type=tensor_type, prepend_batch_axis=prepend_batch_axis)
#
# File /Applications/anaconda3/envs/DL-torch-arm64/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:728, in BatchEncoding.convert_to_tensors(self, tensor_type, prepend_batch_axis)
#     726 elif tensor_type == TensorType.JAX:
#     727     if not is_flax_available():
# --> 728         raise ImportError("Unable to convert output to JAX tensors format, JAX is not installed.")
#     729     import jax.numpy as jnp  # noqa: F811
#     731     as_tensor = jnp.array
#
# ImportError: Unable to convert output to JAX tensors format, JAX is not installed.

# %%
outputs = model(**inputs)
outputs
